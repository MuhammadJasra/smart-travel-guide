# %%
from IPython.display import clear_output


def recommend_destination(age, budget, weather, days_visit, commute_vehicle):
    destinations = {
    "Disneyland": "Disneyland is a magical theme park where dreams come true for children and adults alike.",
    "Paris": "Paris, the capital of France, is renowned for its romantic ambiance, historic landmarks, and artistic treasures.",
    "Santorini": "Santorini, a volcanic island in Greece, is famous for its stunning sunsets, white-washed buildings, and blue-domed churches.",
    "Bangkok": "Bangkok, the capital of Thailand, offers vibrant street life, bustling markets, and affordable accommodations.",
    "Barcelona": "Barcelona, the cosmopolitan capital of Spain’s Catalonia region, is known for its art and architecture.",
    "Maldives": "The Maldives, a tropical paradise in the Indian Ocean, boasts luxurious overwater bungalows and pristine beaches.",
    "Hawaii": "Hawaii, a U.S. state, is an archipelago known for its beautiful beaches, tropical climate, and lush landscapes.",
    "London": "London, the capital of England, offers a rich history, cultural diversity, and iconic landmarks like Big Ben and the Tower of London.",
    "Switzerland": "Switzerland, a landlocked country in the Alps, is famous for its picturesque landscapes, skiing resorts, and chocolate.",
    "Tokyo": "Tokyo, the capital of Japan, is a vibrant metropolis known for its neon-lit streets, diverse food scene, and historic temples.",
    "New York City": "New York City, the largest city in the United States, is a cultural melting pot with iconic landmarks like Times Square and the Statue of Liberty.",
    "Rio de Janeiro": "Rio de Janeiro, Brazil, is famous for its breathtaking beaches, vibrant Carnival celebrations, and iconic Christ the Redeemer statue.",
    "Sydney": "Sydney, Australia, is renowned for its stunning Sydney Opera House, beautiful harbor, and vibrant nightlife.",
    "Rome": "Rome, the capital of Italy, is a city steeped in history with iconic landmarks like the Colosseum, Vatican City, and Trevi Fountain.",
    "Cape Town": "Cape Town, South Africa, offers stunning natural beauty, including Table Mountain, pristine beaches, and vineyards.",
    "Dubai": "Dubai, a city in the United Arab Emirates, is known for its futuristic architecture, luxury shopping, and vibrant nightlife.",
    "Bali": "Bali, Indonesia, is an island paradise known for its lush rice terraces, Hindu temples, and vibrant arts scene.",
    "Amsterdam": "Amsterdam, the capital of the Netherlands, is famous for its picturesque canals, historic buildings, and vibrant cultural scene.",
    "Prague": "Prague, the capital of the Czech Republic, is renowned for its beautiful Old Town Square, historic castles, and charming cobblestone streets.",
    "Athens": "Athens, the capital of Greece, is famous for its ancient monuments, such as the Acropolis and Parthenon.",
    "Venice": "Venice, Italy, is renowned for its picturesque canals, historic architecture, and romantic atmosphere.",
    "Cairo": "Cairo, the capital of Egypt, is known for its ancient pyramids, such as the Great Pyramid of Giza, and historic landmarks.",
    "Machu Picchu": "Machu Picchu, Peru, is an ancient Incan citadel situated high in the Andes Mountains, known for its stunning scenery and archaeological significance.",
    "Berlin": "Berlin, the capital of Germany, is known for its vibrant art scene, historic sites like the Berlin Wall, and cultural diversity.",
    "Seoul": "Seoul, the capital of South Korea, is a bustling metropolis known for its modern skyscrapers, high-tech subways, and pop culture.",
    "Istanbul": "Istanbul, Turkey, is a city that straddles Europe and Asia across the Bosphorus Strait, known for its historic sites such as the Hagia Sophia and Topkapi Palace.",
    "Toronto": "Toronto, Canada, is a diverse city known for its iconic CN Tower, vibrant neighborhoods, and cultural events.",
    "Kyoto": "Kyoto, Japan, is famous for its classical Buddhist temples, as well as gardens, imperial palaces, Shinto shrines, and traditional wooden houses.",
    "San Francisco": "San Francisco, California, is known for its iconic Golden Gate Bridge, cable cars, and eclectic mix of Victorian and modern architecture.",
    "Marrakech": "Marrakech, Morocco, is known for its vibrant souks, historic medina, and beautiful palaces and gardens.",
    "Vienna": "Vienna, Austria, is famous for its cultural events, imperial palaces, historic sites, coffee houses, and vineyards.",
    "St. Petersburg": "St. Petersburg, Russia, is renowned for its beautiful architecture, historic museums, and cultural heritage.",
    "Edinburgh": "Edinburgh, Scotland, is known for its historic and cultural attractions, including Edinburgh Castle, the Royal Mile, and the annual Edinburgh Festival.",
    "Los Angeles": "Los Angeles, California, is a sprawling metropolis known for its entertainment industry, beautiful beaches, and diverse neighborhoods."
}
    
   

    # Age-based recommendation
    if age > 14 and age < 18 :
        if budget =="low":
            if weather == "snowy":
                destination = "Santorini"
            elif weather == "rainy":
                destination = "Athens"
            elif weather == "sunny":
                destination = "Disneyland"
            else:
                print("Please Enter a Valid Weather")
        elif budget == "moderate":
            if weather == "snowy":
                destination = "Bangkok"
            elif weather == "rainy":
                destination = "Barcelona"
            elif weather == "sunny":
                destination = "Maldives"
            else:
                print("Please Enter a Valid Weather")
        elif budget =="high":
            if weather == "snowy":
                destination = "Hawaii"
            elif weather == "rainy":
                destination = "London"
            elif weather == "sunny":
                destination = "Switzerland"
            else:
                print("Please Enter a Valid Weather")
        else:
            print("Please enter a Valid Entry")
    elif age >= 18 and age <= 30:
        if budget =="low":
            if weather == "snowy":
                destination = "Tokyo"
            elif weather == "rainy":
                destination = "Sydney"
            elif weather == "sunny":
                destination = "Rio de Janeiro"
            else:
                print("Please Enter a Valid Weather")
        elif budget == "moderate":
            if weather == "snowy":
                destination = "Rome"
            elif weather == "rainy":
                destination = "Kyoto"
            elif weather == "sunny":
                destination = "Bali"
            else:
                print("Please Enter a Valid Weather")
        elif budget =="high":
            if weather == "snowy":
                destination = "Amsterdam"
            elif weather == "rainy":
                destination = "Dubai"
            elif weather == "sunny":
                destination = "New York City"
            else:
                print("Please Enter a Valid Weather")
        else:
            print("Please enter a Valid Entry")
    elif age > 30 and age < 100:
        if budget =="low":
            if weather == "snowy":
                destination = "Prague"
            elif weather == "rainy":
                destination = "Venice"
            elif weather == "sunny":
                destination = "Cairo"
            else:
                print("Please Enter a Valid Weather")
        elif budget == "moderate":
            if weather == "snowy":
                destination = "Seoul"
            elif weather == "rainy":
                destination = "Istanbul"
            elif weather == "sunny":
                destination = "Los Angeles"
            else:
                print("Please Enter a Valid Weather")
        elif budget =="high":
            if weather == "snowy":
                destination = "Edinburgh"
            elif weather == "rainy":
                destination = "Vienna"
            elif weather == "sunny":
                destination = "St. Petersburg"
            else:
                print("Please Enter a Valid Weather")
        else:
            print("Please enter a Valid Budget")
    else:
        print("Please Enter a Valid entry")

   

    # Days of visit-based recommendation
    if days_visit <= 3:
        transport = "You can explore the city using public transportation such as buses and trains."
    elif days_visit > 3 and days_visit <= 7:
        transport = "Renting a car would be convenient for exploring the nearby attractions."
    else:
        transport = "Consider booking guided tours to make the most of your extended stay."

    return destination, destinations[destination], transport
#The menu options
menu_options = {
     
    "1": "Find a destination that's best for you",  
    "2": "Display all cities",
    "3": "Display cities by weather condition",
    "4": "Exit"
}

#___________________________________________________________
sunny_cities = {
    "Disneyland",
    "Maldives",
    "Hawaii",
    "Tokyo",
    "Dubai",
    "Sydney",
    "Athens",
    "Kyoto",
    "Los Angeles"
    }

snowy_cities = {
    "Paris",
    "Barcelona",
    "London",
    "Rome",
    "Berlin",
    "Toronto",
    "San Francisco",
    "Vienna"
    }

rainy_cities = {
    "Santorini",
    "Bangkok",
    "Switzerland",
    "New York City",
    "Rio de Janeiro",
    "Cape Town",
    "Bali",
    "Amsterdam",
    "Prague",
    "Venice",
    "Cairo",
    "Machu Picchu",
    "Seoul",
    "Istanbul",
    "Marrakech",
    "St. Petersburg",
    "Edinburgh"
    }

cities = {
    "Disneyland",
    "Paris",
    "Santorini",
    "Bangkok",
    "Barcelona",
    "Maldives",
    "Hawaii",
    "London",
    "Switzerland",
    "Tokyo",
    "New York City",
    "Rio de Janeiro",
    "Sydney",
    "Rome",
    "Cape Town",
    "Dubai",
    "Bali",
    "Amsterdam",
    "Prague",
    "Athens",
    "Venice",
    "Cairo",
    "Machu Picchu",
    "Berlin",
    "Seoul",
    "Istanbul",
    "Kyoto",
    "San Francisco",
    "Marrakech",
    "St. Petersburg",
    "Edinburgh",
    "Los Angeles",
    "Vienna"
    }
#___________________________________________________________



# Function to display all cities
def display_all_cities():
    print("List of Cities:")
    return cities

# Function to display cities by weather condition
def display_cities_by_weather(_weather):
    if _weather == "snowy":
        print("Snowy cities:")
        for city in snowy_cities:
            print(city)
    elif _weather == "rainy":
        print("Rainy Cities:")
        for city in rainy_cities:
            print(city)
    elif _weather == "sunny":
        print("Sunny cities:")
        for city in sunny_cities:
            print(city)
    else:
        print("Please Enter a Valid Weather")

# Main program loop
while True:
    # Display the menu
    
    print("\n\n\nMenu:")
    for option, description in menu_options.items():
        print(f"{option}: {description}")

    # Get user input
    choice = input("Enter your choice: \n")

    # Perform actions based on user choice
    if choice == "1":
        # Take input from the user
        age = int(input("Enter your age: "))
        if age < 10 or age > 100:
            print("Please Enter a Valid Age")
            continue
            
        budget_options = ["low", "moderate", "high"]
        budget = input("Enter your budget (low, moderate, high): ").lower()
        if budget not in budget_options:
            print("Please enter a valid budget (low, moderate, high).")
            continue

        weather = input("Enter your preferred weather (sunny, rainy, snowy): ").lower()
        days_visit = int(input("Enter the number of days you plan to visit: "))
        commute_vehicle = input("How do you want to commute there (car, public transport, guided tours): ").lower()

        # Get recommendation
        destination, description, transport = recommend_destination(age, budget, weather, days_visit, commute_vehicle)

        # Output recommendation
        print("\nRecommended Destination:", destination)
        print("About the destination:", description)
        print("Best mode of transportation:", transport)
        
    elif choice == "2":
        all_cities = display_all_cities()  # Get the set of all cities
        for city in all_cities:  # Loop through and print each city
            print(city)
            
            
        
    elif choice == "3":
        weather = input("Enter the weather condition: \n Sunny, Rainy, Snowny ")
        
        display_cities_by_weather(weather)
    
                
                
    elif choice == "4":
        print("Exiting program...")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# Menu:
# 1: Find a destination that's best for you
# 2: Display all cities
# 3: Display cities by weather condition
# 4: Exit
# Enter your choice:
# 1
# Enter your age: 19
# Enter your budget (low, moderate, high): moderate
# Enter your preferred weather (sunny, rainy, snowy): snowy
# Enter the number of days you plan to visit: 7
# How do you want to commute there (car, public transport, guided tours): car
#
# Recommended Destination: Rome
# About the destination: Rome, the capital of Italy, is a city steeped in history with iconic landmarks like the Colosseum, Vatican City, and Trevi Fountain.
# Best mode of transportation: Renting a car would be convenient for exploring the nearby attractions.
#
#
#
# Menu:
# 1: Find a destination that's best for you
# 2: Display all cities
# 3: Display cities by weather condition
# 4: Exit
# Enter your choice:
# 1
# Enter your age: 111
# Please Enter a Valid Age
#
#
#
# Menu:
# 1: Find a destination that's best for you
# 2: Display all cities
# ...
